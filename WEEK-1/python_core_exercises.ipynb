# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}

# --- Task 1: Python Fundamentals, Lists, Tuples, Sets, Dictionaries, Indexing & Slicing ---
print("\n--- Task 1: Data Generation and Basic Structures ---")
# Task 1.1

raw_sensor_data = []

for i in range(100):

    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    device_id = f"DEV{i+1:03}"

    device_type = random.choice(DEVICE_TYPES)

    location = random.choice(LOCATIONS)

    minimum, maximum = READING_RANGES[device_type]
    value = round(random.uniform(minimum, maximum), 2)

    reading = (timestamp, device_id, device_type, location, value)

    raw_sensor_data.append(reading)

for reading in raw_sensor_data[:5]:
    print(reading)














    #task 1.2

temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

#task 1.3

print(temperature_readings[:5])

unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)

#task 1.4

device_stats = {}

# Initialize
for device in DEVICE_TYPES:
    device_stats[device] = (float("inf"), float("-inf"))

# Update min and max
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    current_min, current_max = device_stats[device_type]

    if value < current_min:
        current_min = value

    if value > current_max:
        current_max = value

    device_stats[device_type] = (current_min, current_max)

print(device_stats)

#task 1.5.1

sliced_readings_1 = raw_sensor_data[9:20]

print(sliced_readings_1)

sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_2)

#task 1.5.2

sample_string = "PythonProgrammingIsFun"

substring_1 = sample_string[6:17]

print(substring_1)

substring_2 = sample_string[5::-1]

print(substring_2)

#task 1.5.3

fifth_reading_device_type = raw_sensor_data[4][2]

print(fifth_reading_device_type)

device_type_suffix = fifth_reading_device_type[-6:]

print(device_type_suffix)

#task 2.1

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"

reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"Directory '{reports_dir}' created.")
else:
    print(f"Directory '{reports_dir}' already exists.")


first_timestamp = datetime.datetime.strptime(raw_sensor_data[0][0], "%Y-%m-%d %H:%M:%S")
last_timestamp = datetime.datetime.strptime(raw_sensor_data[-1][0], "%Y-%m-%d %H:%M:%S")

duration = last_timestamp - first_timestamp

days = duration.days
hours = duration.seconds // 3600
minutes = (duration.seconds % 3600) // 60

print(f"Duration: {days} days, {hours} hours, {minutes} minutes")


random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print(random_values)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# --- Task 1: Data Generation and Basic Structures ---
# ('2026-07-19 15:42:32', 'DEV001', 'Light_Sensor', 'Lab1', 616.01)
# ('2026-07-19 15:42:32', 'DEV002', 'Humidity_Sensor', 'Lab1', 41.51)
# ('2026-07-19 15:42:32', 'DEV003', 'Light_Sensor', 'Warehouse', 659.23)
# ('2026-07-19 15:42:32', 'DEV004', 'Light_Sensor', 'OfficeB', 501.71)
# ('2026-07-19 15:42:32', 'DEV005', 'Light_Sensor', 'OfficeA', 542.74)
# [{'timestamp': '2026-07-19 15:42:32', 'device_id': 'DEV006', 'location': 'Lab2', 'temperature_celsius': 23.28}, {'timestamp': '2026-07-19 15:42:32', 'device_id': 'DEV013', 'location': 'Lab1', 'temperature_celsius': 28.22}, {'timestamp': '2026-07-19 15:42:32', 'device_id': 'DEV017', 'location': 'Lab2', 'temperature_celsius': 21.24}, {'timestamp': '2026-07-19 15:42:32', 'device_id': 'DEV018', 'location': 'Warehouse', 'temperature_celsius': 26.6}, {'timestamp': '2026-07-19 15:42:32', 'device_id': 'DEV020', 'location': 'Lab1', 'temperature_celsius': 25.22}]
# {'OfficeA', 'Warehouse', 'Lab2', 'OfficeB', 'Lab1'}
# {'Temperature_Sensor': (18.46, 29.92), 'Humidity_Sensor': (33.4, 77.38), 'Pressure_Sensor': (981.34, 1023.64), 'Light_Sensor': (139.89, 973.03)}
# [('2026-07-19 15:42:32', 'DEV010', 'Light_Sensor', 'Lab1', 338.79), ('2026-07-19 15:42:32', 'DEV011', 'Humidity_Sensor', 'Warehouse', 40.73), ('2026-07-19 15:42:32', 'DEV012', 'Light_Sensor', 'OfficeB', 718.0), ('2026-07-19 15:42:32', 'DEV013', 'Temperature_Sensor', 'Lab1', 28.22), ('2026-07-19 15:42:32', 'DEV014', 'Humidity_Sensor', 'Lab1', 60.04), ('2026-07-19 15:42:32', 'DEV015', 'Humidity_Sensor', 'Lab1', 75.01), ('2026-07-19 15:42:32', 'DEV016', 'Light_Sensor', 'OfficeA', 459.22), ('2026-07-19 15:42:32', 'DEV017', 'Temperature_Sensor', 'Lab2', 21.24), ('2026-07-19 15:42:32', 'DEV018', 'Temperature_Sensor', 'Warehouse', 26.6), ('2026-07-19 15:42:32', 'DEV019', 'Pressure_Sensor', 'Lab1', 1007.24), ('2026-07-19 15:42:32', 'DEV020', 'Temperature_Sensor', 'Lab1', 25.22)]
# [('2026-07-19 15:42:32', 'DEV001', 'Light_Sensor', 'Lab1', 616.01), ('2026-07-19 15:42:32', 'DEV006', 'Temperature_Sensor', 'Lab2', 23.28), ('2026-07-19 15:42:32', 'DEV011', 'Humidity_Sensor', 'Warehouse', 40.73), ('2026-07-19 15:42:32', 'DEV016', 'Light_Sensor', 'OfficeA', 459.22), ('2026-07-19 15:42:32', 'DEV021', 'Pressure_Sensor', 'Lab1', 1008.46), ('2026-07-19 15:42:32', 'DEV026', 'Light_Sensor', 'Warehouse', 528.29), ('2026-07-19 15:42:32', 'DEV031', 'Light_Sensor', 'Warehouse', 524.69), ('2026-07-19 15:42:32', 'DEV036', 'Pressure_Sensor', 'OfficeA', 1005.24), ('2026-07-19 15:42:32', 'DEV041', 'Temperature_Sensor', 'OfficeB', 29.92), ('2026-07-19 15:42:32', 'DEV046', 'Pressure_Sensor', 'Lab1', 1015.54), ('2026-07-19 15:42:32', 'DEV051', 'Pressure_Sensor', 'Lab1', 1020.82), ('2026-07-19 15:42:32', 'DEV056', 'Humidity_Sensor', 'Lab2', 57.82), ('2026-07-19 15:42:32', 'DEV061', 'Pressure_Sensor', 'Lab1', 1013.51), ('2026-07-19 15:42:32', 'DEV066', 'Pressure_Sensor', 'Lab2', 1010.59), ('2026-07-19 15:42:32', 'DEV071', 'Light_Sensor', 'Lab1', 244.59), ('2026-07-19 15:42:32', 'DEV076', 'Light_Sensor', 'OfficeB', 426.15), ('2026-07-19 15:42:32', 'DEV081', 'Humidity_Sensor', 'OfficeB', 40.11), ('2026-07-19 15:42:32', 'DEV086', 'Humidity_Sensor', 'OfficeA', 72.28), ('2026-07-19 15:42:32', 'DEV091', 'Pressure_Sensor', 'OfficeA', 994.05), ('2026-07-19 15:42:32', 'DEV096', 'Pressure_Sensor', 'Warehouse', 1019.96)]
# Programming
# nohtyP
# Light_Sensor
# Sensor
# Directory 'sensor_reports' created.
# Duration: 0 days, 0 hours, 0 minutes
# [171, 194, 200, 157, 129]
